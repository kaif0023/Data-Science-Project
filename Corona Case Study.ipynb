# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Reading File
df=pd.read_csv("C:\\Users\\md kaif\\Downloads\\data sets-20221130T050826Z-001\\data sets\\latest Covid-19 India Status1.csv")
df.head()
# Out:
#         State/UTs  Total Cases  Active  Deaths  Active Ratio (%)  \
# 0     Maharashtra      6122893  117869  123857              1.93
# 1          Kerala      3011694  108400   14108              3.60
# 2       Karnataka      2862338   39626   35601              1.38
# 3      Tamil Nadu      2506848   34076   33196              1.36
# 4  Andhra Pradesh      1911231   32356   12919              1.69
#
#    Death Ratio (%)
# 0             2.02
# 1             0.47
# 2             1.24
# 3             1.32
# 4             0.68

# %%
df.shape
# Out:
# (36, 6)

# %%
df.dtypes
# Out:
# State/UTs            object
# Total Cases           int64
# Active                int64
# Deaths                int64
# Active Ratio (%)    float64
# Death Ratio (%)     float64
# dtype: object

# %%
df.head(5)
# Out:
#         State/UTs  Total Cases  Active  Deaths  Active Ratio (%)  \
# 0     Maharashtra      6122893  117869  123857              1.93
# 1          Kerala      3011694  108400   14108              3.60
# 2       Karnataka      2862338   39626   35601              1.38
# 3      Tamil Nadu      2506848   34076   33196              1.36
# 4  Andhra Pradesh      1911231   32356   12919              1.69
#
#    Death Ratio (%)
# 0             2.02
# 1             0.47
# 2             1.24
# 3             1.32
# 4             0.68

# %%
df.tail(5)
# Out:
#                                    State/UTs  Total Cases  Active  Deaths  \
# 31                                    Sikkim        21573    1975     311
# 32                                    Ladakh        20143     183     204
# 33  Dadra and Nagar Haveli and Daman and Diu        10576      38       4
# 34                               Lakshadweep         9965     246      49
# 35                       Andaman and Nicobar         7491      14     128
#
#     Active Ratio (%)  Death Ratio (%)
# 31              9.15             1.44
# 32              0.91             1.01
# 33              0.36             0.04
# 34              2.47             0.49
# 35              0.19             1.71

# %%
df["State/UTs"].unique()
# Out:
# array(['Maharashtra', 'Kerala', 'Karnataka', 'Tamil Nadu',
#        'Andhra Pradesh', 'Uttar Pradesh', 'West Bengal', 'Delhi',
#        'Chhattisgarh', 'Rajasthan', 'Odisha', 'Gujarat', 'Madhya Pradesh',
#        'Haryana', 'Bihar', 'Telengana', 'Punjab', 'Assam', 'Jharkhand',
#        'Uttarakhand', 'Jammu and Kashmir', 'Himachal Pradesh', 'Goa',
#        'Puducherry', 'Manipur', 'Tripura', 'Chandigarh', 'Meghalaya',
#        'Arunachal Pradesh', 'Nagaland', 'Mizoram', 'Sikkim', 'Ladakh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Lakshadweep',
#        'Andaman and Nicobar'], dtype=object)

# %%
df["State/UTs"].nunique() ## Number Of States
# Out:
# 36

# %%
### Find Out The Total Cases Of Each State/Ut
k=df.groupby(["State/UTs"])["Total Cases"].agg(["max","min","sum"]).sort_values(by="max",ascending=False)
k
# Out:
#                                               max      min      sum
# State/UTs
# Maharashtra                               6122893  6122893  6122893
# Kerala                                    3011694  3011694  3011694
# Karnataka                                 2862338  2862338  2862338
# Tamil Nadu                                2506848  2506848  2506848
# Andhra Pradesh                            1911231  1911231  1911231
# Uttar Pradesh                             1706934  1706934  1706934
# West Bengal                               1508223  1508223  1508223
# Delhi                                     1434780  1434780  1434780
# Chhattisgarh                               996689   996689   996689
# Rajasthan                                  952887   952887   952887
# Odisha                                     929788   929788   929788
# Gujarat                                    824029   824029   824029
# Madhya Pradesh                             790070   790070   790070
# ...

# %%
k=k.reset_index()

# %%
plt.figure(figsize=(20,10),edgecolor="black")
plt.bar(k["State/UTs"],k["sum"])
plt.xticks(rotation=90);
plt.show;

# %%
# Find OUt The Top 10 And Bottom 10 Affected States

# %%
k.head(10)
# Out:
#         State/UTs      max      min      sum
# 0     Maharashtra  6122893  6122893  6122893
# 1          Kerala  3011694  3011694  3011694
# 2       Karnataka  2862338  2862338  2862338
# 3      Tamil Nadu  2506848  2506848  2506848
# 4  Andhra Pradesh  1911231  1911231  1911231
# 5   Uttar Pradesh  1706934  1706934  1706934
# 6     West Bengal  1508223  1508223  1508223
# 7           Delhi  1434780  1434780  1434780
# 8    Chhattisgarh   996689   996689   996689
# 9       Rajasthan   952887   952887   952887

# %%
sns.barplot(x=k["State/UTs"].head(10),y=k["sum"],data=k)
plt.xticks(rotation=90);

# %%
k.tail(10)
# Out:
#                                    State/UTs    max    min    sum
# 26                                Chandigarh  61780  61780  61780
# 27                                 Meghalaya  52712  52712  52712
# 28                         Arunachal Pradesh  38283  38283  38283
# 29                                  Nagaland  25663  25663  25663
# 30                                   Mizoram  22703  22703  22703
# 31                                    Sikkim  21573  21573  21573
# 32                                    Ladakh  20143  20143  20143
# 33  Dadra and Nagar Haveli and Daman and Diu  10576  10576  10576
# 34                               Lakshadweep   9965   9965   9965
# 35                       Andaman and Nicobar   7491   7491   7491

# %%
plt.figure(figsize=(15,7))
sns.barplot(x=k["State/UTs"].tail(10),y=k["sum"],data=k)
plt.xticks(rotation=90);

# %%
## Distribution Of Total Cases State_Wise
plt.figure(figsize=(20,8))
#labels = df.index
plt.pie(x=k["sum"].head(10), data=df, labels=k['State/UTs'].head(10),autopct='%.1f%%')
plt.title("Total cases in each state", fontsize = 24) 
#plt.tight_layout() 
plt.show()

# %%
plt.figure(figsize=(20,8))
#labels = df.index
plt.pie(x=k["sum"].tail(10), data=df, labels=k['State/UTs'].tail(10),autopct='%.1f%%')
plt.title("Total cases in each state", fontsize = 24) 
#plt.tight_layout() 
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(df['State/UTs'],df['Active Ratio (%)'],color='red',marker='o')
plt.xticks(rotation=90,fontsize=13.5)
plt.yticks(fontsize=13.5)
plt.xlabel('State', fontsize=15)
plt.ylabel('Active Ratio', fontsize=15)
plt.title("Line Plot for Active Cases Ratio",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(df['State/UTs'],df['Death Ratio (%)'],color='red',marker='o')
plt.xticks(rotation=90,fontsize=13.5)
plt.yticks(fontsize=13.5)
plt.xlabel('State', fontsize=15)
plt.ylabel('Active Ratio', fontsize=15)
plt.title("Line Plot for Death Ratio",fontsize=15)
plt.show()

# %%
'''punjab had highest death ratio
while uttarakhand had second Highest
Dadra and Nagar Haveli and Daman and Diu had lowest '''
# Out:
# 'punjab had highest death ratio\nwhile uttarakhand had second Highest\nDadra and Nagar Haveli and Daman and Diu had lowest '

# %%
#Feature Engineering
recovered_cases = df['Total Cases'] - (df['Active'] + df['Deaths'])
df["Recovered Cases"]=df['Total Cases'] - (df['Active'] + df['Deaths'])

# %%
df.head(5)
# Out:
#         State/UTs  Total Cases  Active  Deaths  Active Ratio (%)  \
# 0     Maharashtra      6122893  117869  123857              1.93
# 1          Kerala      3011694  108400   14108              3.60
# 2       Karnataka      2862338   39626   35601              1.38
# 3      Tamil Nadu      2506848   34076   33196              1.36
# 4  Andhra Pradesh      1911231   32356   12919              1.69
#
#    Death Ratio (%)  Recovered Cases
# 0             2.02          5881167
# 1             0.47          2889186
# 2             1.24          2787111
# 3             1.32          2439576
# 4             0.68          1865956
