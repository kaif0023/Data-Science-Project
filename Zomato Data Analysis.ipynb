# %% [markdown]
# ## Importing Necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading The Data Of Zomato

# %%
df=pd.read_csv("C:\\Users\\md kaif\\Downloads\\data sets-20221130T050826Z-001\\data sets\\zomato.csv")

# %% [markdown]
# ## Reading The Top 5 Rows

# %%
df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ## Reading The Data of Zomato Country Code

# %%
df1=pd.read_excel("C:\\Users\\md kaif\\Downloads\\data sets-20221130T050826Z-001\\data sets\\Zomato_Country-Code.xlsx")

# %% [markdown]
# ## Reading The Top 5 Rows

# %%
df1.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %% [markdown]
# ## Checking The Info Of Both The data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df1.columns.unique()
# Out:
# Index(['Country Code', 'Country'], dtype='object')

# %%
df1["Country Code"].unique()
# Out:
# array([  1,  14,  30,  37,  94, 148, 162, 166, 184, 189, 191, 208, 214,
#        215, 216], dtype=int64)

# %%
df.columns.unique()
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df2=pd.merge(df,df1,on="Country Code",how="left")
df2.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df2.shape
# Out:
# (9551, 22)

# %% [markdown]
# ## Checking The Info ()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df2.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
df2.columns.unique()
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# ## Filling The Missing Values In Cuisines

# %%
df2["Cuisines"].fillna(df["Cuisines"].mode()[0],inplace=True)

# %%
df2.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# ## Checking Duplicacy in The Data

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.sample(n=10)
# Out:
#       Restaurant ID                      Restaurant Name  Country Code  \
# 99         17284390  The Catch Seafood Room & Oyster Bar           216
# 8533           1460                    Chawla's Chic Inn             1
# 8433           3796                Deez Biryani & Kebabs             1
# 4064       18264980                         Food Code 99             1
# 2916       18239781                Aristocrat Sweet Shop             1
# 6643            974                 Paramjeet Machi Wala             1
# 4691       18350118              Dialogue Lounge & Cafí©             1
# 3809           2217                               Tamura             1
# 5445         300945                        Any Time Food             1
# 7815       18377900                 Khan Tandoori Nights             1
#
#            City                                            Address  \
# 99       Albany       2332 Whispering Pines Road, Albany, GA 31707
# ...

# %%
df2.groupby(["Restaurant Name"])["Aggregate rating"].value_counts().iloc[90:150]
# Out:
# Restaurant Name                            Aggregate rating
# 7 Stick                                    2.8                 1
# 736 A.D.                                   4.1                 1
# 7st by Mumbai Spices                       3.4                 1
# 7th Heaven                                 3.7                 1
# 9 Mars Lounge                              2.5                 1
# 9 Scoops                                   3.6                 1
# 9 is Mine                                  2.6                 1
# 99 North Restaurant                        3.6                 1
# @Mango                                     4.1                 1
# A & A Pagliai's Pizza                      4.3                 1
# A 1 - Snacks and food corner               2.5                 1
# A Dong Restaurant                          4.4                 1
# A Figueira Rubaiyat                        4.3                 1
# A Lot Like Cake                            3.1                 1
# ...

# %%
for i in df2.columns:
    print(i,".....-----.....",df2[i].unique())
# Out:
# Restaurant ID .....-----..... [6317637 6304287 6300002 ... 5915807 5916112 5927402]
# Restaurant Name .....-----..... ['Le Petit Souffle' 'Izakaya Kikufuji' 'Heat - Edsa Shangri-La' ...
#  'Huqqa' 'A\x81ô\x81ôk Kahve' "Walter's Coffee Roastery"]
# Country Code .....-----..... [162  30 216  14  37 184 214   1  94 148 215 166 189 191 208]
# City .....-----..... ['Makati City' 'Mandaluyong City' 'Pasay City' 'Pasig City' 'Quezon City'
#  'San Juan City' 'Santa Rosa' 'Tagaytay City' 'Taguig City' 'Brasí_lia'
#  'Rio de Janeiro' 'Sí£o Paulo' 'Albany' 'Armidale' 'Athens' 'Augusta'
#  'Balingup' 'Beechworth' 'Boise' 'Cedar Rapids/Iowa City' 'Chatham-Kent'
#  'Clatskanie' 'Cochrane' 'Columbus' 'Consort' 'Dalton' 'Davenport'
#  'Des Moines' 'Dicky Beach' 'Dubuque' 'East Ballina' 'Fernley' 'Flaxton'
#  'Forrest' 'Gainesville' 'Hepburn Springs' 'Huskisson' 'Inverloch'
#  'Lakes Entrance' 'Lakeview' 'Lincoln' 'Lorn' 'Macedon' 'Macon' 'Mayfield'
# ...

# %%
df2.drop(columns=["Locality","Locality","Locality Verbose","Restaurant ID","Latitude","Longitude","Address","Switch to order menu"],inplace=True)

# %%
df2.head()
# Out:
#           Restaurant Name  Country Code              City  \
# 0        Le Petit Souffle           162       Makati City
# 1        Izakaya Kikufuji           162       Makati City
# 2  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                    Ooma           162  Mandaluyong City
# 4             Sambo Kojin           162  Mandaluyong City
#
#                            Cuisines  Average Cost for two          Currency  \
# 0        French, Japanese, Desserts                  1100  Botswana Pula(P)
# 1                          Japanese                  1200  Botswana Pula(P)
# 2  Seafood, Asian, Filipino, Indian                  4000  Botswana Pula(P)
# 3                   Japanese, Sushi                  1500  Botswana Pula(P)
# 4                  Japanese, Korean                  1500  Botswana Pula(P)
#
#   Has Table booking Has Online delivery Is delivering now  Price range  \
# 0               Yes                  No                No            3
# ...

# %%
sns.barplot(x="Aggregate rating",data=df2)
# Out:
# <AxesSubplot:xlabel='Aggregate rating'>

# %%
df2.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.ylabel("Number Of Restaurents")
sns.countplot(x="Country",data=df2)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
z=df2.groupby(["Country","Has Online delivery"]).size().reset_index()
z
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %%
finaldf=df2[df2["Country"]=="India"]
finaldf
# Out:
#                             Restaurant Name  Country Code   City  \
# 624                              Jahanpanah             1   Agra
# 625                     Rangrezz Restaurant             1   Agra
# 626                 Time2Eat - Mama Chicken             1   Agra
# 627   Chokho Jeeman Marwari Jain Bhojanalya             1   Agra
# 628                          Pinch Of Spice             1   Agra
# ...                                     ...           ...    ...
# 9271                               D Cabana             1  Vizag
# 9272                               Kaloreez             1  Vizag
# 9273                                Plot 17             1  Vizag
# 9274                       Vista - The Park             1  Vizag
# 9275               Flying Spaghetti Monster             1  Vizag
#
#                                                Cuisines  Average Cost for two  \
# 624                               North Indian, Mughlai                   850
# ...

# %%
finaldf.head()
# Out:
#                            Restaurant Name  Country Code  City  \
# 624                             Jahanpanah             1  Agra
# 625                    Rangrezz Restaurant             1  Agra
# 626                Time2Eat - Mama Chicken             1  Agra
# 627  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628                         Pinch Of Spice             1  Agra
#
#                            Cuisines  Average Cost for two            Currency  \
# 624           North Indian, Mughlai                   850  Indian Rupees(Rs.)
# 625           North Indian, Mughlai                   700  Indian Rupees(Rs.)
# 626                    North Indian                   500  Indian Rupees(Rs.)
# 627                      Rajasthani                   400  Indian Rupees(Rs.)
# 628  North Indian, Chinese, Mughlai                  1000  Indian Rupees(Rs.)
#
#     Has Table booking Has Online delivery Is delivering now  Price range  \
# ...

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.countplot(x="City",data=finaldf)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
k=finaldf["City"].value_counts().reset_index()
k
# Out:
#            index  City
# 0      New Delhi  5473
# 1        Gurgaon  1118
# 2          Noida  1080
# 3      Faridabad   251
# 4      Ghaziabad    25
# 5      Ahmedabad    21
# 6       Guwahati    21
# 7        Lucknow    21
# 8   Bhubaneshwar    21
# 9       Amritsar    21
# 10          Pune    20
# 11    Puducherry    20
# 12         Patna    20
# 13      Ludhiana    20
# 14        Ranchi    20
# 15         Surat    20
# 16      Vadodara    20
# 17        Nashik    20
# 18        Nagpur    20
# 19        Mysore    20
# 20        Mumbai    20
# 21      Varanasi    20
# 22     Mangalore    20
# 23          Agra    20
# 24         Kochi    20
# 25       Kolkata    20
# 26      Dehradun    20
# 27     Allahabad    20
# 28    Aurangabad    20
# 29     Bangalore    20
# 30        Bhopal    20
# 31       Chennai    20
# 32    Coimbatore    20
# 33           Goa    20
# 34        Indore    20
# 35        Jaipur    20
# 36        Kanpur    20
# 37         Vizag    20
# 38    Chandigarh    18
# ...

# %%
plt.figure(figsize=(50,30))
plt.pie(x=k["City"],labels=k["index"],autopct="%0.01F%%")
plt.legend()

# %%
k["index"].iloc[5:43]=k["index"].iloc[5:43].apply(lambda x:"others")
# Out:
# C:\Users\md kaif\AppData\Local\Temp\ipykernel_10164\3658293856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k["index"].iloc[5:43]=k["index"].iloc[5:43].apply(lambda x:"others")

# %%
k1=k.groupby(["index"])["City"].sum().reset_index()

# %%
plt.figure(figsize=(20,7))
plt.pie(x=k1["City"],labels=k1["index"],autopct="%0.01F%%")
plt.legend()

# %% [markdown]
# ## Statistical Summary

# %%
finaldf.describe()
# Out:
#        Country Code  Average Cost for two  Price range  Aggregate rating  \
# count        8652.0           8652.000000  8652.000000       8652.000000
# mean            1.0            623.370319     1.721683          2.523324
# std             0.0            595.676124     0.852544          1.510986
# min             1.0              0.000000     1.000000          0.000000
# 25%             1.0            300.000000     1.000000          2.100000
# 50%             1.0            450.000000     2.000000          3.100000
# 75%             1.0            700.000000     2.000000          3.600000
# max             1.0           8000.000000     4.000000          4.900000
#
#               Votes
# count   8652.000000
# mean     137.212552
# std      428.039513
# min        0.000000
# 25%        4.000000
# 50%       24.000000
# 75%      100.000000
# max    10934.000000

# %%
## Which REstaurent is Expensive Based on Cuisines Type Of Each City

# %%
f=finaldf[finaldf["Average Cost for two"]!=0]
f
# Out:
#                             Restaurant Name  Country Code   City  \
# 624                              Jahanpanah             1   Agra
# 625                     Rangrezz Restaurant             1   Agra
# 626                 Time2Eat - Mama Chicken             1   Agra
# 627   Chokho Jeeman Marwari Jain Bhojanalya             1   Agra
# 628                          Pinch Of Spice             1   Agra
# ...                                     ...           ...    ...
# 9271                               D Cabana             1  Vizag
# 9272                               Kaloreez             1  Vizag
# 9273                                Plot 17             1  Vizag
# 9274                       Vista - The Park             1  Vizag
# 9275               Flying Spaghetti Monster             1  Vizag
#
#                                                Cuisines  Average Cost for two  \
# 624                               North Indian, Mughlai                   850
# ...

# %%
k=f.groupby(["City","Cuisines"])["Average Cost for two"].mean().reset_index().sort_values(by=["City","Average Cost for two"])
k
# Out:
#        City                                           Cuisines  \
# 10     Agra                                         Rajasthani
# 3      Agra                                       North Indian
# 12     Agra                             South Indian, Desserts
# 1      Agra                                     Italian, Pizza
# 8      Agra                            North Indian, Fast Food
# ...     ...                                                ...
# 2203  Vizag  Chinese, Thai, Burmese, Vietnamese, Tibetan, J...
# 2207  Vizag                                            Italian
# 2196  Vizag          American, North Indian, Thai, Continental
# 2210  Vizag               North Indian, Chinese, Mediterranean
# 2204  Vizag                          Continental, North Indian
#
#       Average Cost for two
# 10                   400.0
# 3                    500.0
# 12                   550.0
# 1                    700.0
# 8                    700.0
# ...                    ...
# ...

# %%
k.head(13)
# Out:
#     City                                     Cuisines  Average Cost for two
# 10  Agra                                   Rajasthani                 400.0
# 3   Agra                                 North Indian                 500.0
# 12  Agra                       South Indian, Desserts                 550.0
# 1   Agra                               Italian, Pizza                 700.0
# 8   Agra                      North Indian, Fast Food                 700.0
# 11  Agra                Rajasthani, Gujarati, Mughlai                 800.0
# 0   Agra  Chinese, Italian, Continental, North Indian                1000.0
# 6   Agra               North Indian, Chinese, Mughlai                1000.0
# 5   Agra  North Indian, Chinese, Continental, Mughlai                1100.0
# 4   Agra           North Indian, Chinese, Continental                1500.0
# 9   Agra                        North Indian, Mughlai                1710.0
# ...

# %% [markdown]
# ## Which Cuisines Type Restaurent Has Highest And Lowest Ratings In  Each City

# %%
f.groupby(["Cuisines"])["City"].value_counts().head(40)
# Out:
# Cuisines                                                  City
# Afghani                                                   Gurgaon        2
#                                                           New Delhi      2
# Afghani, Mughlai, Chinese                                 New Delhi      1
# Afghani, North Indian                                     Gurgaon        1
# Afghani, North Indian, Pakistani, Arabian                 New Delhi      1
# American                                                  New Delhi      4
#                                                           Noida          2
# American, Asian, European, Seafood                        New Delhi      1
# American, Asian, North Indian, Mexican, South Indian      New Delhi      1
# American, British, Continental                            New Delhi      1
# American, Burger, Cafe                                    Bangalore      1
# American, Burger, Fast Food                               Mumbai         1
# ...

# %%
k=f.groupby(["Cuisines","City"])["Aggregate rating"].agg(["mean"]).reset_index().sort_values(by=["City"])
k
# Out:
#                                          Cuisines   City  mean
# 1427                                 North Indian   Agra  3.60
# 1799                        North Indian, Mughlai   Agra  3.84
# 1186                               Italian, Pizza   Agra  4.40
# 525   Chinese, Italian, Continental, North Indian   Agra  4.20
# 1514           North Indian, Chinese, Continental   Agra  3.80
# ...                                           ...    ...   ...
# 367                     Cafe, Fast Food, American  Vizag  3.80
# 903                                     Fast Food  Vizag  3.75
# 771                     Continental, North Indian  Vizag  4.10
# 1992                             Pizza, Fast Food  Vizag  4.45
# 1578         North Indian, Chinese, Mediterranean  Vizag  4.90
#
# [2214 rows x 3 columns]

# %%
type(123)

type(20-12-2022)
# Out:
# int

# %%
type(19/12/2022)
# Out:
# float

# %%
type(20-12-2022)
# Out:
# int

# %%
type(np.nan)
# Out:
# float

# %%
finaldf["Aggregate rating"].agg(["mean","max","min"])
# Out:
# mean    2.523324
# max     4.900000
# min     0.000000
# Name: Aggregate rating, dtype: float64

# %%
ratings=finaldf.groupby(["Aggregate rating","Rating color","Rating text"]).size().reset_index().rename(columns={0:"Rating Count"})

# %%
plt.xticks(rotation=90)
sns.barplot(x="Aggregate rating",y="Rating Count",data=ratings,palette=["white","red","yellow","green","blue"])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
finaldf[finaldf["City"]=="New Delhi"].sort_values(by="Aggregate rating",ascending=False)
# Out:
#                 Restaurant Name  Country Code       City  \
# 3013         Naturals Ice Cream             1  New Delhi
# 3601  Indian Accent - The Manor             1  New Delhi
# 4298             Masala Library             1  New Delhi
# 6656               Kopper Kadai             1  New Delhi
# 3012                MOB Brewpub             1  New Delhi
# ...                         ...           ...        ...
# 5671             Chicken Darwar             1  New Delhi
# 5670            Cheffron Bakery             1  New Delhi
# 5669       Captain Food Factory             1  New Delhi
# 5668          Brown Town Bakers             1  New Delhi
# 8032       Zareen's Dastarkhwan             1  New Delhi
#
#                                  Cuisines  Average Cost for two  \
# 3013                            Ice Cream                   150
# 3601                        Modern Indian                  4000
# 4298                        Modern Indian                  5000
# ...

# %%
sns.countplot(x="Rating color",data=ratings,palette=["black","red","orange","yellow","green","green"]);

# %%
k2=finaldf.groupby(["City","Restaurant Name","Aggregate rating"])["Votes"].mean().reset_index()
k2
# Out:
#        City                        Restaurant Name  Aggregate rating  Votes
# 0      Agra                           Bon Barbecue               3.8   57.0
# 1      Agra                         Chapter 1 Cafe               3.9   98.0
# 2      Agra  Chokho Jeeman Marwari Jain Bhojanalya               4.0   87.0
# 3      Agra                 Dasaprakash Restaurant               4.1  121.0
# 4      Agra           Dawat-e-Nawab - Radisson Blu               3.8   46.0
# ...     ...                                    ...               ...    ...
# 8110  Vizag                            Six Degrees               4.1   75.0
# 8111  Vizag                     Sri Sairam Parlour               4.2  270.0
# 8112  Vizag                             Tea Trails               3.7   57.0
# 8113  Vizag             The Square - Hotel Novotel               4.1  125.0
# 8114  Vizag                       Vista - The Park               3.8   74.0
#
# [8115 rows x 4 columns]

# %% [markdown]
# ## How Many Restaurent Not Rated

# %%
k1=finaldf[finaldf["Aggregate rating"]==0.0]
k1.groupby(["City"])["Rating text"].value_counts()
# Out:
# City       Rating text
# Faridabad  Not rated       100
# Ghaziabad  Not rated         2
# Gurgaon    Not rated       228
# New Delhi  Not rated      1425
# Noida      Not rated       384
# Name: Rating text, dtype: int64

# %% [markdown]
# ## How Many Restaurents Offer Online Delivery , Prior Table Booking To Their Customers

# %%
print("the number of restaurants which gives online delivery  and proir table booking option----",len(finaldf[(finaldf["Has Online delivery"]=="Yes") & (finaldf["Has Table booking"]=="Yes")]))
print("the number of restaurants which gives only online delivery  and no proir table booking option----",len(finaldf[(finaldf["Has Online delivery"]=="Yes") & (finaldf["Has Table booking"]=="No")]))
print("the number of restaurants which gives only proir table booking option and no online delievery----",len(finaldf[(finaldf["Has Online delivery"]=="No") & (finaldf["Has Table booking"]=="Yes")]))
print("the number of restaurants which gives neither option ----",len(finaldf[(finaldf["Has Online delivery"]=="No") & (finaldf["Has Table booking"]=="No")]))
# Out:
# the number of restaurants which gives online delivery  and proir table booking option---- 427
# the number of restaurants which gives only online delivery  and no proir table booking option---- 1996
# the number of restaurants which gives only proir table booking option and no online delievery---- 684
# the number of restaurants which gives neither option ---- 5545
